# %%
import collections
import pandas as pd
words=[]
total_w_c=[]
word=[]
counts=[]
file=open("comment.txt","r+")
wordcount={}
for word in file.read().split():
    
        word = word.lower()

        if word not in wordcount:
            wordcount[word] = 1
        else:
            wordcount[word] += 1
for count,v in wordcount.items():
    words.append(count)
    total_w_c.append(v)
    
test_df = pd.DataFrame({'Words':words,'Counts': total_w_c})

df=test_df.sort_values(by=['Counts'],ascending=False)
df.reset_index(drop='index', inplace=True)
df=df[['Words','Counts']]
df
# Out:
#                  Words  Counts
# 0                  the    5240
# 1                  and    2771
# 2                    a    2241
# 3                   to    2149
# 4                    i    2022
# 5                   of    1569
# 6                  was    1523
# 7                wings    1414
# 8                   is    1040
# 9                   in    1027
# 10                were     947
# 11                 for     929
# 12                 but     898
# 13                  we     870
# 14                  it     835
# 15                they     797
# 16                that     767
# 17             buffalo     700
# 18                 not     688
# 19                  on     683
# 20                 you     659
# 21                 are     590
# 22                with     580
# 23                this     568
# 24                  my     561
# 25                have     550
# 26                 had     533
# 27                  at     501
# 28                 bar     471
# ...

# %%
df.to_csv('word_count.csv')

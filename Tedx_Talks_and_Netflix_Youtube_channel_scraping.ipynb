# %% [markdown]
# # Youtube Channels Scraping

# %% [markdown]
# Using this code you can scrape YouTube channel like Netflix, TedxTalks, Whitehouse and more. This code will save all details in CSV file

# %%
from bs4 import BeautifulSoup
import re, requests, csv, time
from requests import get
    
# set youtube channel name here
channel_name = "whitehouse"

def get_soup(url):
    #open url and return BeautifulSoup object, or None if site does not exist
    result = requests.get(url)
    if result.status_code != 200: return None
    time.sleep(5) # slow down as per youtube 'terms of use' to human speed
    return BeautifulSoup(result.text, 'html.parser')

def channel_section_links():
    #list of { 'title': , 'link':  }
    soup = get(f"https://www.youtube.com/user/{channel_name}/playlists")
    html_soup = BeautifulSoup(soup.text, 'html.parser')
    

    play_list_atags = html_soup.find_all('a', {'href': re.compile(f"{channel_name}/playlists")})
    
    elements = [{'title': x.text.strip(), "link": fix_url(x['href'])} for x in play_list_atags if
                x.span and ('shelf_id=0' not in x['href'])] # filter out play lists
    print("printing elements")
    
   
    if len(elements) == 0: # no sections, make up no sections section with default link
        elements = [ {'title':'no sections',
                      'link':f'https://youtube.com/{channel_name}/playlists'}]
    
    return elements


def fix_url(url):  # correct relative urls back to absolute urls
    if url[0] == '/': return 'https://www.youtube.com' + url
    else: return url


def get_playlists(section):
   
    print(f"  getting playlists for section: {section['title']}")
    soup = get_soup(section['link'])
    if soup == None: # no playlist, create dummy playlist and default link
        return [{'title':'No Playlists', 'link':f'https://youtube.com/{channel_name}/videos'}]
    atags = soup('a', class_="yt-uix-tile-link")
   
    playlists = []
    for a in atags:  # find title and link
        title = a.text
        if title != "Liked videos": # skip these
            link = fix_url(a['href'])
            playlists.append({'title':title, 'link':link})
    if playlists == []: return [{'title':'No Playlists',
                                 'link':f'https://youtube.com/{channel_name}/videos'}]
    
    
   
    playlists=playlists[1:2]#Set number of playlists
   # list[:11]
    
    return playlists

def add_videos(playlist):
    #find videos in playlist[link] and add their info as playlist[videos] as list
    soup = get_soup(playlist['link'])
    print(f"    getting videos for playlist: {playlist['title']}")
    items = soup('a', class_="yt-uix-tile-link") # items are list of video a links from list
    videos = []
    for i in items: 
        d = {} # collect video info in dict
        d['title'] = i.text.strip()
        if d['title'] == '[Private video]':# To skip the private videos 
            continue
        if d['title'] =='[Deleted video]':# To skip the deleted videos 
            continue
        link = fix_url(i['href'])
        d['link'] = link
        t = i.find_next('span', { 'aria-label': True})
        d['time'] = t.text if t else 'NA'
        print(f"      open video '{d['title']}' for details", end=" ")# printing the title of video

        vsoup = get_soup(link) # now get video page and pull information from it
        print("* read, now processing",end="")
        
        views= vsoup.find("div", class_='watch-view-count').text
        
        d['views'] = ''.join(c for c in views if c in "0123456789")
        d['publication_date'] = vsoup.find('strong',
                                class_="watch-time-text").text[len('Published on ')-1:]
        d['description'] = vsoup.find('div',id='watch-description-text').text
        id = vsoup.find('meta', itemprop="videoId")['content']
        d['short_link'] = f'https://youtu.be/{id}'
        likebutton = vsoup.find('button', class_="like-button-renderer-like-button")
        if likebutton.find('span',class_ = 'yt-uix-button-content').text==[]:
            d['likes']=0
        else:
            d['likes'] = likebutton.find('span',class_ = 'yt-uix-button-content').text
        disbutton = vsoup.find('button',class_='like-button-renderer-dislike-button')
        d['dislikes'] = disbutton.find('span',class_ = 'yt-uix-button-content').text
        videos.append(d)
        print("* finished video")

        playlist['videos'] = videos # add new key to this playlist of list of video infos

def tag(t,c): return f'<{t}>{c}</{t}>' # return html tag with content
def link(text, url): return f'{text}' # return a tag with content and link


def csv_out(channel, sections):
    #create and output channel_name.csv file for import into a spreadsheet or DB
    headers = 'channel,section,playlist,video,' \
              'link,time,views,publication date,likes,dislikes,description'.split(',')

    with open(f'{channel}.csv', "w",encoding="utf-8") as csv_file:
        csvf = csv.writer(csv_file, delimiter=',')
        csvf.writerow(headers)
        for section in sections:
            for playlist in section['playlists']:
                for video in playlist['videos']:
                    v = video
                    line = [ channel, section['title'], playlist['title'], v['title']]
                    line.extend([v['short_link'],v['time'], v['views'], v['publication_date'],
                                 v['likes'], v['dislikes'], v['description']])
                    csvf.writerow(line)

if __name__ == '__main__':
    

    print("finding sections")
    sections = channel_section_links()
    for section in sections:
        section['playlists'] = get_playlists(section)
        for playlist in section['playlists']:
            add_videos(playlist)

    
    csv_out(channel_name, sections) # create a csv file of video info for import into spreadsheet

    print(f"Program Complete,\n  '{channel_name}.htm' and" \
          f" '{channel_name}.csv' have been written to current directory")
# Out:
# finding sections
# printing elements
#   getting playlists for section: no sections
#     getting videos for playlist: Vice President Pence
#       open video 'Vice President Pence Delivers Remarks at the 37th Annual National Peace Officers' Memorial Service' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks During a Protocolary Meeting at the OAS' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at the National Rifle Association Leadership Forum' for details * read, now processing* finished video
#       open video 'Vice President Pence Participates in the Swearing-in Ceremony of the U.S. Ambassador to Germany' for details * read, now processing* finished video
#       open video 'Swearing-In Ceremony for the U.S. Permanent Representative to the Organization of American States' for details * read, now processing* finished video
#       open video 'Vice President Pence Holds a Lunch in Honor of the President of France' for details * read, now processing* finished video
#       open video 'Vice President Pence Participates in a Swearing-in for Jim Bridenstine as Administrator of NASA' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at the First Plenary Session of the Summit of the Americas' for details * read, now processing* finished video
#       open video 'President Trump Holds a Listening Session with High School Students and Teachers' for details * read, now processing* finished video
#       open video 'Vice President Pence Leads the Second Meeting of the National Space Council' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at the Second Meeting of the National Space Council' for details * read, now processing* finished video
#       open video 'Vice President Mike Pence Visits Japan' for details * read, now processing* finished video
#       open video 'Vice President Mike Pence is briefed on U.S. Missile Defense Capabilities in Alaska' for details * read, now processing* finished video
#       open video 'Vice President Pence Participates in the Swearing In Ceremony for Sam Brownback' for details * read, now processing* finished video
#       open video 'Vice President Pence Visits Yad Vashem' for details * read, now processing* finished video
#       open video 'Vice President Pence in the Middle East' for details * read, now processing* finished video
#       open video 'Vice President Pence Visits Yad Vashem and the Western Wall' for details * read, now processing* finished video
#       open video 'Vice President Pence in Israel' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks to US Troops in the Middle East' for details * read, now processing* finished video
#       open video 'Vice President Pence in Jordan' for details * read, now processing* finished video
#       open video 'Vice President Pence in Egypt' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Joint Statements with Prime Minister Benjamin Netanyahu of Israel' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at a Reception for the Annual March for Life Event' for details * read, now processing* finished video
#       open video 'Vice President Pence Lays a Wreath at the Martin Luther King Jr. Memorial' for details * read, now processing* finished video
#       open video 'Vice President Pence Remarks to the Troops' for details * read, now processing* finished video
#       open video 'Christmas at the Vice President's Home' for details * read, now processing* finished video
#       open video 'Vice President Pence Participates in a Wreath Laying Ceremony and Delivers Remarks' for details * read, now processing* finished video
#       open video 'Vice President Pence Participates in a U.S.- Japan Economic Dialogue' for details * read, now processing* finished video
#       open video 'Vice President Pence Hosts National Space Council' for details * read, now processing* finished video
#       open video 'Vice President Pence Participates in Tax Reform Events' for details * read, now processing* finished video
#       open video 'Vice President Pence Swears in US Ambassador to Canada Kelly Knight Craft' for details * read, now processing* finished video
#       open video 'Vice President Pence Participates in a Meeting with Maine Governor Paul LePage' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at a UN Security Council High-Level Debate' for details * read, now processing* finished video
#       open video 'Vice President Pence and Veterans Affairs Secretary David Shulkin Host Honor Flight Veterans' for details * read, now processing* finished video
#       open video 'Vice President Pence Participates in a Swearing-in Ceremony for U.S. Surgeon General' for details * read, now processing* finished video
#       open video 'Vice President Pence in Miami' for details * read, now processing* finished video
#       open video 'Vice President Pence in Chile' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks to the Argentine and Latin American Business Community' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at the Adriatic Charter Summit' for details * read, now processing* finished video
#       open video 'Vice President Pence in Georgia' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks in Estonia' for details * read, now processing* finished video
#       open video 'Vice President Pence Swears In U.S. Ambassador to Japan William F. Hagerty IV' for details * read, now processing* finished video
#       open video 'Presidential Advisory Commission on Election Integrity' for details * read, now processing* finished video
#       open video 'Vice President Pence Hosts a Roundtable Discussion' for details * read, now processing* finished video
#       open video 'Presidential Advisory Commission on Election Integrity' for details * read, now processing* finished video
#       open video 'Vice President Pence Participates in a Listening Session with the Philanthropy Roundtable' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at the Kennedy Space Center' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at Tendon Manufacturing, Inc.' for details * read, now processing* finished video
#       open video 'Vice President Pence Participates in a Healthcare Listening Session with Small Business Owners' for details * read, now processing* finished video
#       open video 'Vice President Pence Speaks at the U.S.-India Business Council’s 42nd Annual Leadership Summit' for details * read, now processing* finished video
#       open video 'Vice President Pence Joins CMS Administrator Seema Verma for a Listening Session' for details * read, now processing* finished video
#       open video 'Vice President Pence Offers Remarks to Troops' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at the Focus on the Family 40th Anniversary Celebration' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at the Wilson Center' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at the Associated Builders and Contractors Legislative Day' for details * read, now processing* finished video
#       open video 'Vice President Pence Speaks at the National Summit on Crime Reduction and Public Safety' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at HHS' for details * read, now processing* finished video
#       open video 'Vice President Pence Speaks at the National Association of Manufacturers 2017 Manufacturing Summit' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks on Prosperity and Security in Central America' for details * read, now processing* finished video
#       open video 'Vice President Pence Speaks at the National Association of Home Builders 2017 Legislative Conference' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks Regarding Health Care' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers the Keynote Address at the Faith & Freedom Coalition's Patriot's Gala' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks to Airmen, Service Members and Their Families' for details * read, now processing* finished video
#       open video 'Vice President Pence Gives Remarks at an Infrastructure Summit' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at the 2017 Astronaut Selection Announcement' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at the National Catholic Prayer Breakfast' for details * read, now processing* finished video
#       open video 'Vice President Pence Hosts the Annual Project Hero Memorial Day Bike Ride' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers the Commencement Address at the United States Naval Academy' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at Cajun Industries' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Keynote Address at the University of Notre Dame Commencement Ceremony' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at an Armed Forces Day Celebration' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Keynote Address at Grove City College's 137th Commencement Ceremony' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at an AAPI Heritage Month Reception' for details * read, now processing* finished video
#       open video 'Vice President Pence Participates in a Swearing-in Ceremony for Robert Lighthizer' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at the World Summit in Defense of Persecuted Christians' for details * read, now processing* finished video
#       open video 'Vice President Pence Hosts Military Families' for details * read, now processing* finished video
#       open video 'Vice President Pence Hosts Honor Flight Veterans' for details * read, now processing* finished video
#       open video 'Vice President Pence Hosts a Cinco de Mayo Reception' for details * read, now processing* finished video
#       open video 'Vice President Pence Speaks at the Susan B. Anthony List’s 2017 Campaign for Life Gala' for details * read, now processing* finished video
#       open video 'Vice President Pence Participates in an Israel Independence Day Commemoration Event' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at the National Small Business Week Awards Program' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at the Christening Ceremony for the USS Indiana (SSN-789)' for details * read, now processing* finished video
#       open video 'Vice President Pence Participates in a Swearing-In Ceremony for Alex Acosta as Secretary of Labor' for details * read, now processing* finished video
#       open video 'Vice President Pence Makes Remarks to US Service Members Abroad the USS Ronald Reagan' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks to the Korean Business Community' for details * read, now processing* finished video
#       open video 'Vice President Pence Participates in a Joint Press Conference' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks' for details * read, now processing* finished video
#       open video 'Vice President Pence Participates in a Swearing-in for the U.S. Ambassador to Israel, David Friedman' for details * read, now processing* finished video
#       open video 'Vice President Pence Participates in a Swearing-in Ceremony for the U.S. Ambassador to Israel' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at the AIPAC Policy Conference' for details * read, now processing* finished video
#       open video 'Vice President Pence Makes Remarks at Foster Supply, Inc' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at Mac Paper Inc' for details * read, now processing* finished video
#       open video 'Vice President Pence Swears-in Director of National Intelligence Dan Coats' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at the American Ireland Fund 25th Annual National Gala' for details * read, now processing* finished video
#       open video 'Vice President Pence Participates in the Swearing-in of the Administrator of CMS, Seema Verma' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at Harshaw Trane' for details * read, now processing* finished video
#       open video 'Vice President Pence Gives Keynote Remarks at the Latino Coalition's Policy Summit' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at Blain’s Farm and Fleet Distribution Center' for details * read, now processing* finished video
#       open video 'Vice President Pence Delivers Remarks at Frame USA' for details * read, now processing* finished video
#       open video 'Vice President Pence Participates in a Swearing-In' for details * read, now processing* finished video
# Program Complete,
#   'whitehouse.htm' and 'whitehouse.csv' have been written to current directory
